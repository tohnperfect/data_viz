# %% [markdown]
# <a href="https://colab.research.google.com/github/tohnperfect/data_viz/blob/main/Quiz4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
Q4 = data2_df = pd.read_excel('/content/passenger-covid19.xlsx',sheet_name='Data63-64')
Q4
# Out:
#    ขนคน/ขนสินค้า โหมดการเดินทาง  ... 2021-03-13 00:00:00 2021-03-14 00:00:00
# 0      ขนคน (คน)          ทางบก  ...             51204.0             58371.0
# 1      ขนคน (คน)          ทางบก  ...                 NaN                 NaN
# 2      ขนคน (คน)          ทางบก  ...             11373.0             12455.0
# 3     ขนคน (คัน)          ทางบก  ...            940739.0            870772.0
# 4     ขนคน (คัน)          ทางบก  ...           1348121.0           1211478.0
# 5     ขนคน (คัน)          ทางบก  ...           1305116.0           1192083.0
# 6     ขนคน (คัน)          ทางบก  ...           1090319.0           1045273.0
# 7     ขนคน (คัน)          ทางบก  ...                 NaN                 NaN
# 8      ขนคน (คน)          ทางบก  ...              3629.0              3798.0
# 9      ขนคน (คน)          ทางบก  ...                 NaN                 NaN
# 10     ขนคน (คน)          ทางบก  ...            632056.0            565401.0
# ...

# %%
from datetime import datetime

# %%
Q4.columns = [i.strftime('%Y-%m-%d') if isinstance(i, datetime) else i for i in Q4.columns]
Q4
# Out:
#    ขนคน/ขนสินค้า โหมดการเดินทาง  ... 2021-03-13 2021-03-14
# 0      ขนคน (คน)          ทางบก  ...    51204.0    58371.0
# 1      ขนคน (คน)          ทางบก  ...        NaN        NaN
# 2      ขนคน (คน)          ทางบก  ...    11373.0    12455.0
# 3     ขนคน (คัน)          ทางบก  ...   940739.0   870772.0
# 4     ขนคน (คัน)          ทางบก  ...  1348121.0  1211478.0
# 5     ขนคน (คัน)          ทางบก  ...  1305116.0  1192083.0
# 6     ขนคน (คัน)          ทางบก  ...  1090319.0  1045273.0
# 7     ขนคน (คัน)          ทางบก  ...        NaN        NaN
# 8      ขนคน (คน)          ทางบก  ...     3629.0     3798.0
# 9      ขนคน (คน)          ทางบก  ...        NaN        NaN
# 10     ขนคน (คน)          ทางบก  ...   632056.0   565401.0
# 11     ขนคน (คน)          ทางบก  ...   116540.0   114120.0
# 12     ขนคน (คน)          ทางบก  ...        NaN        NaN
# 13    ขนคน (คัน)          ทางบก  ...        NaN        NaN
# 14    ขนคน (คัน)          ทางบก  ...        NaN        NaN
# ...

# %%
Q4.columns
# Out:
# Index(['ขนคน/ขนสินค้า', 'โหมดการเดินทาง', 'รูปแบบการเดินทาง',
#        'สาธารณะ/ส่วนบุคคล', 'หน่วยงาน', 'ยานพาหนะ/ท่า', '2020-01-01',
#        '2020-01-02', '2020-01-03', '2020-01-04',
#        ...
#        '2021-03-05', '2021-03-06', '2021-03-07', '2021-03-08', '2021-03-09',
#        '2021-03-10', '2021-03-11', '2021-03-12', '2021-03-13', '2021-03-14'],
#       dtype='object', length=445)

# %%
Q4_don_muang_airport = Q4[Q4['ยานพาหนะ/ท่า']=='ท่าอากาศยานดอนเมือง ขาออกประเทศ']
Q4_don_muang_airport
# Out:
#    ขนคน/ขนสินค้า โหมดการเดินทาง  ... 2021-03-13 2021-03-14
# 38     ขนคน (คน)       ทางอากาศ  ...        3.0        1.0
#
# [1 rows x 445 columns]

# %%
Q4_don_muang_airport['2020-03-25']
# Out:
# 38    96.0
# Name: 2020-03-25, dtype: float64

# %%
Q4[Q4['ยานพาหนะ/ท่า']=='ท่าอากาศยานดอนเมือง ขาออกประเทศ']['2020-03-25']
# Out:
# 38    96.0
# Name: 2020-03-25, dtype: float64

# %% [markdown]
# ### Working with datetime
#
# https://towardsdatascience.com/working-with-datetime-in-pandas-dataframe-663f7af6c587
#
# https://realpython.com/python-datetime/

# %%
Q4_2 = data2_df = pd.read_excel('/content/passenger-covid19.xlsx',sheet_name='Data63-64')
Q4_2
# Out:
#    ขนคน/ขนสินค้า โหมดการเดินทาง  ... 2021-03-13 00:00:00 2021-03-14 00:00:00
# 0      ขนคน (คน)          ทางบก  ...             51204.0             58371.0
# 1      ขนคน (คน)          ทางบก  ...                 NaN                 NaN
# 2      ขนคน (คน)          ทางบก  ...             11373.0             12455.0
# 3     ขนคน (คัน)          ทางบก  ...            940739.0            870772.0
# 4     ขนคน (คัน)          ทางบก  ...           1348121.0           1211478.0
# 5     ขนคน (คัน)          ทางบก  ...           1305116.0           1192083.0
# 6     ขนคน (คัน)          ทางบก  ...           1090319.0           1045273.0
# 7     ขนคน (คัน)          ทางบก  ...                 NaN                 NaN
# 8      ขนคน (คน)          ทางบก  ...              3629.0              3798.0
# 9      ขนคน (คน)          ทางบก  ...                 NaN                 NaN
# 10     ขนคน (คน)          ทางบก  ...            632056.0            565401.0
# ...

# %%
Q4_2.columns
# Out:
# Index([    'ขนคน/ขนสินค้า',    'โหมดการเดินทาง',  'รูปแบบการเดินทาง',
#        'สาธารณะ/ส่วนบุคคล',          'หน่วยงาน',      'ยานพาหนะ/ท่า',
#        2020-01-01 00:00:00, 2020-01-02 00:00:00, 2020-01-03 00:00:00,
#        2020-01-04 00:00:00,
#        ...
#        2021-03-05 00:00:00, 2021-03-06 00:00:00, 2021-03-07 00:00:00,
#        2021-03-08 00:00:00, 2021-03-09 00:00:00, 2021-03-10 00:00:00,
#        2021-03-11 00:00:00, 2021-03-12 00:00:00, 2021-03-13 00:00:00,
#        2021-03-14 00:00:00],
#       dtype='object', length=445)

# %%
from datetime import date,datetime

# %%
datetime(day=25,month=3,year=2020)
# Out:
# datetime.datetime(2020, 3, 25, 0, 0)

# %%
Q4_2[Q4_2['ยานพาหนะ/ท่า']=='ท่าอากาศยานดอนเมือง ขาออกประเทศ'][datetime(day=25,month=3,year=2020)]
# Out:
# 38    96.0
# Name: 2020-03-25 00:00:00, dtype: float64
